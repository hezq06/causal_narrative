# %%
# %reload_ext autoreload
# %autoreload 2
import matplotlib
# matplotlib.use('TkAgg')
# %matplotlib
# %config Completer.use_jedi = False

# %%
from causal_narrative.fmriutil import *
from causal_narrative.datautil import *

# %%
coef_b, _, _ = load_data("../python/bottom/coef_mat_for_all_subs.data")
# Out:
# Data load from  ../python/bottom/coef_mat_for_all_subs.data

# %%
coef_t, _, _ = load_data("../python/top/coef_mat_for_all_subs.data")
# Out:
# Data load from  ../python/top/coef_mat_for_all_subs.data

# %%
fsplot = FSPlot()
# Out:
# Data load from  /home/hezq17/nilearn_data/fsaverage6/infl_left.gii.gz

# %%
fsplot.plot(coef_t-coef_b, clim = [-0.03,0.03])
# Out:
# /home/hezq17/anaconda3/envs/causal/lib/python3.8/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
